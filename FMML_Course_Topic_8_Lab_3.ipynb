# %% [markdown]
# <a href="https://colab.research.google.com/github/Raparthikavya/FMML_LAB_2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 07:07:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  82.9MB/s    in 0.8s
#
# 2024-03-29 07:07:04 (82.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12530  1802.07581v1  We characterize the asymptotic performance of ...  stat
# 18643   1106.4872v1  The proliferation of online information source...    cs
# 14337  cs/9809112v1  This paper addresses the issue of {\sc pos} ta...    cs
# 11702  1610.01959v1  It was shown recently that the $K$ L1-norm pri...    cs
# 12986   1304.4610v2  The paper studies the problem of recovering a ...    cs
# ...             ...                                                ...   ...
# 8759   1803.08337v1  We propose a novel way to measure and understa...    cs
# 3500   1709.07359v1  Generative Adversarial Networks (GANs) produce...  stat
# 16343  1701.03185v2  Sequence-to-sequence models have been applied ...    cs
# 20633  1608.07223v1  A checkers-like model game with a simplified s...    cs
# 8454   1609.07495v1  We tackle the problem of learning a rotation i...    cs
#
#                                                    title  year  \
# 12530  Universal Hypothesis Testing with Kernels: Asy...  2018
# 18643   Wrapper Maintenance: A Machine Learning Approach  2011
# 14337  On the Evaluation and Comparison of Taggers: T...  1998
# 11702  Efficient L1-Norm Principal-Component Analysis...  2016
# 12986  Spectral Compressed Sensing via Structured Mat...  2013
# ...                                                  ...   ...
# 8759                  What do Deep Networks Like to See?  2018
# 3500     Class-Splitting Generative Adversarial Networks  2017
# 16343  Generating High-Quality and Informative Conver...  2017
# 20633       Is a good offensive always the best defense?  2016
# 8454   A Rotation Invariant Latent Factor Model for M...  2016
#
#                                                 keywords
# 12530  [characterize, asymptotic, performance, nonpar...
# 18643  [proliferation, information, increased, extrac...
# 14337  [addresses, evaluation, evaluation, performed,...
# 11702  [principal, components, calculated, advantageo...
# 12986  [recovering, spectrally, specifically, dimensi...
# ...                                                  ...
# 8759   [understand, convolutional, quantifying, autoe...
# 3500   [generative, adversarial, systematically, info...
# 16343  [conversation, generation, conversation, trans...
# 20633  [simplified, extensive, simulations, different...
# 8454   [invariant, comprised, dimensional, projection...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12530    [characterize, asymptotic, performance, nonpar...
# 18643    [proliferation, information, increased, extrac...
# 14337    [addresses, evaluation, evaluation, performed,...
# 11702    [principal, components, calculated, advantageo...
# 12986    [recovering, spectrally, specifically, dimensi...
#                                ...
# 1793     [classification, predictor, hierarchical, stru...
# 5726     [generalization, classifier, classification, f...
# 18269    [conditioning, developed, smarandache, qualita...
# 5161     [clustering, optimizing, objective, partitions...
# 35924    [theoretic, framework, introduced, conditional...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8655 words.
# Out of those 4543 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7a710cbb-0c38-449d-99a5-ad94deec472b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a710cbb-0c38-449d-99a5-ad94deec472b")) {                    Plotly.newPlot(                        "7a710cbb-0c38-449d-99a5-ad94deec472b",                        [{"x":["hypothesis","performance","universal","efficient","deviation","statistical","criterion","experiments","otherwise","optimality","asymptotic","probability","computationally","nonparametric","exponential","constraint","asymptotically","characterize","hoeffding","convergence","properties","discrepancy","attention","correctly","discovered","obtaining","automatically","extraction","structural","maintenance","important","extracting","identifying","increased","precision","successfully","proliferation","validated","generation","generated","monitored","development","resulting","verification","applications","algorithm","information","conclusion","comparison","experimentation","currently","reference","distortion","invalidate","addresses","comparing","evaluation","accuracies","improvement","performed","optimization","principal","advantageous","theoretical","superiority","calculated","dimensionality","component","components","reduction","alternative","calculates","diagnosis","calculation","comparable","computational","demonstrated","potentially","frequency","prohibitive","suboptimal","experimental","characterizing","logarithmic","underlying","resolution","specifically","dimension","paradigms","proportional","structure","incoherence","instances","structured","spectrally","minimization","numerical","arranging","applicability","recovering","dimensional","frequencies","conventional","representation","completion","robustness","dictionary","compressed","conditions","furthermore","benchmark","posterior","increasing","dimensions","contribution","parameters","variational","truncated","saturates","investigate","independently","benchmarks","approaches","independence","posteriors","separation","distribution","introduced","denoising","distributions","application","contributes","corresponding","independent","inference","functional","attributes","conceptual","extension","relations","knowledge","description","uniqueness","complexity","databases","restriction","reasoning","introduce","dependencies","positional","projections","syntactic","expressive","attribute","appearance","decidable","inclusion","thoroughly","reconstructing","subsequently","different","acquisition","traditional","simulated","difficulties","compressive","celebrated","algorithmic","objective","directional","companion","formulation","approximations","naturally","particular","riemannian","arbitrary","geometric","programming","nonconvex","minimizers","deflation","initializations","converges","processing","understanding","curvature","advantage","sufficiently","minimizer","collection","recovered","spherical","excellent","baselines","fundamental","prediction","autoencoders","advertising","embedding"],"y":[57,858,30,425,14,152,42,616,15,26,11,182,93,16,54,112,12,41,0,114,226,14,174,42,22,54,175,118,58,12,334,72,73,45,83,86,8,32,154,175,5,132,157,36,420,807,702,13,140,16,61,65,29,2,56,64,238,19,155,118,314,40,7,151,30,29,55,106,104,78,95,5,54,21,104,305,103,52,57,10,14,397,16,20,123,114,161,47,14,13,321,5,111,105,3,64,86,2,42,27,180,11,103,360,41,96,48,30,132,172,195,38,102,52,71,268,50,4,1,138,38,85,427,20,1,26,200,116,36,98,225,8,131,123,190,45,58,19,77,96,333,61,9,231,58,9,112,337,42,1,26,39,27,34,75,2,6,10,14,32,777,46,185,74,16,15,3,37,171,16,6,84,31,52,260,12,78,64,145,11,2,1,6,30,274,166,6,94,12,4,74,12,3,29,53,86,222,17,5,106],"type":"bar"},{"x":["hypothesis","performance","universal","efficient","deviation","statistical","criteri ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4543,), (4543, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8216666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Solving</span> <span style=''>the</span> <span style=''>Wastewater</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Treatment</span> <span style=''>Plant</span> <span style=''>Problem</span> <span style=''>with</span> <span style=''>SMT</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Wastewater</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Treatment</span> <span style=''>Plant</span> <span style=''>Problem</span> <span style=''>a</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(0, 255, 0, 0.5862068965517241);'>scheduling</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>several</span> <span style=''>tools</span> <span style=''>on</span> <span style=''>it</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>for</span> <span style=''>a</span> <span style=''>naive</span> <span style=''>modeling</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>SMT</span> <span style=''>solvers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>other</span> <span style=''>tools</span> <span style=''>ranging</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>mathematical</span> <span style='background-color:rgba(0, 255, 0, 0.45728643216080395);'>programming</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3827160493827161);'>constraint</span> <span style='background-color:rgba(0, 255, 0, 0.45728643216080395);'>programming</span> <span style=''>We</span> <span style=''>use</span> <span style=''>both</span> <span style=''>real</span> <span style=''>and</span> <span style=''>randomly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style='background-color:rgba(0, 255, 0, 0.49122807017543857);'>benchmarks</span> <span style=''>From</span> <span style=''>this</span> <span style=''>and</span> <span style=''>similar</span> <span style=''>results</span> <span style=''>we</span> <span style=''>claim</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convenience</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developing</span> <span style=''>compiler</span> <span style=''>front</span> <span style=''>ends</span> <span style=''>being</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>translate</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3827160493827161);'>constraint</span> <span style='background-color:rgba(0, 255, 0, 0.45728643216080395);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.913978494623656);'>languages</span> <span style=''>to</span> <span style=''>the</span> <span style=''>SMT</span> <span style=''>LIB</span> <span style=''>standard</span> <span style=''>language</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relevance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determination</span> <span style=''>For</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recurring</span> <span style=''>problem</span> <span style=''>when</span> <span style=''>building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>and</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>instance</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>space</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>belief</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>has</span> <span style=''>been</span> <span style=''>adressed</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Relevance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determination</span> <span style=''>(ARD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>ARD</span> <span style=''>for</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <span style=''>using</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>fast</span> <span style=''>and</span> <span style=''>scalable</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>on</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>dataset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrating</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contracting</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representati ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>and</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>models</span> <span style=''>(SEMs)</span> <span style=''>from</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.33098591549295775);'>inference</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>works</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.35943060498220647);'>dimensional</span> <span style=''>regime</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>linear</span> <span style=''>SEMs</span> <span style=''>from</span> <span style=''>purely</span> <span style='background-color:rgba(255, 0, 0, 0.6470588235294117);'>observational</span> <span style=''>data</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>three</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>identifiability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.35042735042735046);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>when</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>from</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>SEM</span> <span style=''>over</span> <span style=''>p</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>maximum</span> <span style=''>degree</span> <span style=''>d</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>recovers</span> <span style=''>the</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graph</span> <span style=''>(DAG)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>SEM</span> <span style=''>under</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>identifiability</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Mini</span> <span style=''>Batch</span> <span style=''>Spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>The</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>the</span> <span style=''>spectrum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>matrices</span> <span style=''>hinders</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>to</span> <span style=''>large</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>recover</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tractability</span> <span style=''>they</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>affect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>based</span> <span style=''>on</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Crucially</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>recovers</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>spectrum</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>matrices</span> <span style=''>in</span> <span style=''>the</span> <span style=''>limit</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>and</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>is</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>on</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>up</span> <span style=''>to</span> <span style=''>half</span> <span style=''>a</span> <span style=''>million</span> <span style=''>samples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>and</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperform</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09747420846673782)
# 	segmentation (0.06367840626111704)
# 	representation (0.128068303094984)
# 	architecture (0.08288865172536464)
# 	information (0.2497331910352188)
# 	experimental (0.14123087869085735)
# 	detection (0.11810743507648523)
# 	different (0.27641408751334046)
# 	recognition (0.12842404838135896)
# 	convolutional (0.14656705798648167)
#
# Some Statistics words are:
# 	stochastic (0.14278531925590748)
# 	theoretical (0.15082956259426847)
# 	variables (0.14429361488185016)
# 	distribution (0.16993464052287582)
# 	statistical (0.15887380593262945)
# 	estimation (0.18250377073906485)
# 	algorithm (0.4067370537958773)
# 	inference (0.19004524886877827)
# 	dimensional (0.19205630970336854)
# 	regression (0.1739567621920563)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="704199c4-4e33-4ab3-8b40-bc861aaaee93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("704199c4-4e33-4ab3-8b40-bc861aaaee93")) {                    Plotly.newPlot(                        "704199c4-4e33-4ab3-8b40-bc861aaaee93",                        [{"x":["hypothesis","performance","universal","efficient","deviation","statistical","criterion","experiments","otherwise","optimality","asymptotic","probability","computationally","nonparametric","exponential","constraint","asymptotically","characterize","hoeffding","convergence","properties","discrepancy","attention","correctly","discovered","obtaining","automatically","extraction","structural","maintenance","important","extracting","identifying","increased","precision","successfully","proliferation","validated","generation","generated","monitored","development","resulting","verification","applications","algorithm","information","conclusion","comparison","experimentation","currently","reference","distortion","invalidate","addresses","comparing","evaluation","accuracies","improvement","performed","optimization","principal","advantageous","theoretical","superiority","calculated","dimensionality","component","components","reduction","alternative","calculates","diagnosis","calculation","comparable","computational","demonstrated","potentially","frequency","prohibitive","suboptimal","experimental","characterizing","logarithmic","underlying","resolution","specifically","dimension","paradigms","proportional","structure","incoherence","instances","structured","spectrally","minimization","numerical","arranging","applicability","recovering","dimensional","frequencies","conventional","representation","completion","robustness","dictionary","compressed","conditions","furthermore","benchmark","posterior","increasing","dimensions","contribution","parameters","variational","truncated","saturates","investigate","independently","benchmarks","approaches","independence","posteriors","separation","distribution","introduced","denoising","distributions","application","contributes","corresponding","independent","inference","functional","attributes","conceptual","extension","relations","knowledge","description","uniqueness","complexity","databases","restriction","reasoning","introduce","dependencies","positional","projections","syntactic","expressive","attribute","appearance","decidable","inclusion","thoroughly","reconstructing","subsequently","different","acquisition","traditional","simulated","difficulties","compressive","celebrated","algorithmic","objective","directional","companion","formulation","approximations","naturally","particular","riemannian","arbitrary","geometric","programming","nonconvex","minimizers","deflation","initializations","converges","processing","understanding","curvature","advantage","sufficiently","minimizer","collection","recovered","spherical","excellent","baselines","fundamental","prediction","autoencoders","advertising","embedding","heterogeneous","preserving","mainstream","demonstrate","unobserved","attitudes","representations","sentiment","recommendation","framework","predicting","establish","classification","dynamical","metabolic","repeatable","iterative","mechanisms","conscious","evolution","thermodynamics","specified","algorithms","nonlinear","nonlinearity","observations","simulations","superposition","illustrate","aperiodic","techniques","observing","simulation","languages","transferred","heuristics","reinforcement","heuristic","improvements","explicitly","effectiveness","recognition","reframing","annotation","importantly","shortcomings","selection","classifier","variation","portuguese","informative","historical","morphosyntactic","represented","documents","inter ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	hoeffding
# 	distinguishable
# 	biomarkers
# 	prognostic
# 	semiparametric
# 	elliptical
# 	transelliptical
# 	stagewise
# 	narrowing
# 	isotropic
# 	reciprocity
# 	coherently
# 	missforest
# 	suspected
# 	multipartite
# 	reassignment
# 	particulars
# 	parallelized
# 	perturbing
# 	visualisation
# Some words which never appear in Statistics papers:
# 	invalidate
# 	spectrally
# 	arranging
# 	syntactic
# 	decidable
# 	repeatable
# 	conscious
# 	portuguese
# 	morphosyntactic
# 	relatedness
# 	predicates
# 	specifications
# 	alldifferent
# 	attracting
# 	javascript
# 	nonmonotonic
# 	revisions
# 	perceptually
# 	mammographic
# 	transcribing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.062505742198267e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7775
